# %% [markdown]
# # Analyze data

# %% [markdown]
# # 1. Import

# %% [markdown]
# ## 1.1 Packages

# %%
import pandas as pd
import yfinance as yf

import pprint
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ## 1.2 Options

# %% [markdown]
# # 2. Data

# %%
apple = yf.Ticker("AAPL")
pp.pprint(apple.info)
# Out:
# {   '52WeekChange': 0.40746212,
#     'SandP52WeekChange': 0.14593434,
#     'address1': 'One Apple Park Way',
#     'ask': 236.02,
#     'askSize': 1,
#     'auditRisk': 7,
#     'averageAnalystRating': '2.0 - Buy',
#     'averageDailyVolume10Day': 45548530,
#     'averageDailyVolume3Month': 51162249,
#     'averageVolume': 51162249,
#     'averageVolume10days': 45548530,
#     'beta': 1.178,
#     'bid': 235.93,
#     'bidSize': 2,
#     'boardRisk': 1,
#     'bookValue': 4.438,
#     'city': 'Cupertino',
#     'companyOfficers': [   {   'age': 63,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Mr. Timothy D. Cook',
#                                'title': 'CEO & Director',
#                                'totalPay': 16239562,
#                                'unexercisedValue': 0,
#                                'yearBorn': 1961},
#                            {   'age': 60,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Mr. Jeffrey E. Williams',
#                                'title': 'Chief Operating Officer',
#                                'totalPay': 4637585,
#                                'unexercisedValue': 0,
#                                'yearBorn': 1964},
#                            {   'age': 60,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Ms. Katherine L. Adams',
#                                'title': 'Senior VP, General Counsel & '
#                                         'Secretary',
#                                'totalPay': 4618064,
#                                'unexercisedValue': 0,
#                                'yearBorn': 1964},
#                            {   'age': 57,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': "Ms. Deirdre  O'Brien",
#                                'title': 'Chief People Officer & Senior VP of '
#                                         'Retail',
#                                'totalPay': 4613369,
#                                'unexercisedValue': 0,
#                                'yearBorn': 1967},
#                            {   'age': 52,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Mr. Kevan  Parekh',
#                                'title': 'Senior VP & CFO',
#                                'unexercisedValue': 0,
#                                'yearBorn': 1972},
#                            {   'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Mr. Chris  Kondo',
#                                'title': 'Senior Director of Corporate '
#                                         'Accounting',
#                                'unexercisedValue': 0},
#                            {   'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Suhasini  Chandramouli',
#                                'title': 'Director of Investor Relations',
#                                'unexercisedValue': 0},
#                            {   'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Ms. Kristin Huguet Quayle',
#                                'title': 'Vice President of Worldwide '
#                                         'Communications',
#                                'unexercisedValue': 0},
#                            {   'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Mr. Greg  Joswiak',
#                                'title': 'Senior Vice President of Worldwide '
#                                         'Marketing',
#                                'unexercisedValue': 0},
#                            {   'age': 50,
#                                'exercisedValue': 0,
#                                'fiscalYear': 2023,
#                                'maxAge': 1,
#                                'name': 'Mr. Adrian  Perica',
#                                'title': 'Vice President of Corporate '
#                                         'Development',
#                                'unexercisedValue': 0,
#                                'yearBorn': 1974}],
#     'compensationAsOfEpochDate': 1703980800,
#     'compensationRisk': 3,
#     'corporateActions': [],
#     'country': 'United States',
#     'cryptoTradeable': False,
#     'currency': 'USD',
#     'currentPrice': 235.93,
#     'currentRatio': 0.923,
#     'customPriceAlertConfidence': 'HIGH',
#     'dateShortInterest': 1739491200,
#     'dayHigh': 240.07,
#     'dayLow': 234.7,
#     'debtToEquity': 145.0,
#     'displayName': 'Apple',
#     'dividendDate': 1739404800,
#     'dividendRate': 1.0,
#     'dividendYield': 0.42,
#     'earningsCallTimestampEnd': 1738274400,
#     'earningsCallTimestampStart': 1738274400,
#     'earningsGrowth': 0.101,
#     'earningsQuarterlyGrowth': 0.071,
#     'earningsTimestamp': 1738272600,
#     'earningsTimestampEnd': 1746446400,
#     'earningsTimestampStart': 1746010740,
#     'ebitda': 137352003584,
#     'ebitdaMargins': 0.34706002,
#     'enterpriseToEbitda': 26.117,
#     'enterpriseToRevenue': 9.064,
#     'enterpriseValue': 3587181641728,
#     'epsCurrentYear': 7.33728,
#     'epsForward': 8.31,
#     'epsTrailingTwelveMonths': 6.25,
#     'esgPopulated': False,
#     'exDividendDate': 1739145600,
#     'exchange': 'NMS',
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'executiveTeam': [],
#     'fiftyDayAverage': 239.9608,
#     'fiftyDayAverageChange': -4.0308075,
#     'fiftyDayAverageChangePercent': -0.016797775,
#     'fiftyTwoWeekChangePercent': 40.746212,
#     'fiftyTwoWeekHigh': 260.1,
#     'fiftyTwoWeekHighChange': -24.170013,
#     'fiftyTwoWeekHighChangePercent': -0.09292585,
#     'fiftyTwoWeekLow': 164.08,
#     'fiftyTwoWeekLowChange': 71.84999,
#     'fiftyTwoWeekLowChangePercent': 0.43789607,
#     'fiftyTwoWeekRange': '164.08 - 260.1',
#     'financialCurrency': 'USD',
#     'firstTradeDateMilliseconds': 345479400000,
#     'fiveYearAvgDividendYield': 0.59,
#     'floatShares': 14998187904,
#     'forwardEps': 8.31,
#     'forwardPE': 28.391092,
#     'freeCashflow': 93833871360,
#     'fullExchangeName': 'NasdaqGS',
#     'fullTimeEmployees': 150000,
#     'gmtOffSetMilliseconds': -18000000,
#     'governanceEpochDate': 1740787200,
#     'grossMargins': 0.46519002,
#     'grossProfits': 184102993920,
#     'hasPrePostMarketData': True,
#     'heldPercentInsiders': 0.02268,
#     'heldPercentInstitutions': 0.62804,
#     'impliedSharesOutstanding': 15262499840,
#     'industry': 'Consumer Electronics',
#     'industryDisp': 'Consumer Electronics',
#     'industryKey': 'consumer-electronics',
#     'irWebsite': 'http://investor.apple.com/',
#     'isEarningsDateEstimate': True,
#     'language': 'en-US',
#     'lastDividendDate': 1739145600,
#     'lastDividendValue': 0.25,
#     'lastFiscalYearEnd': 1727481600,
#     'lastSplitDate': 1598832000,
#     'lastSplitFactor': '4:1',
#     'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets '
#                            'smartphones, personal computers, tablets, '
#                            'wearables, and accessories worldwide. The company '
#                            'offers iPhone, a line of smartphones; Mac, a line '
#                            'of personal computers; iPad, a line of '
#                            'multi-purpose tablets; and wearables, home, and '
#                            'accessories comprising AirPods, Apple TV, Apple '
#                            'Watch, Beats products, and HomePod. It also '
#                            'provides AppleCare support and cloud services; and '
#                            'operates various platforms, including the App '
#                            'Store that allow customers to discover and '
#                            'download applications and digital content, such as '
#                            'books, music, video, games, and podcasts, as well '
#                            'as advertising services include third-party '
#                            'licensing arrangements and its own advertising '
#                            'platforms. In addition, the company offers various '
#                            'subscription-based services, such as Apple Arcade, '
#                            'a game subscription service; Apple Fitness+, a '
#                            'personalized fitness service; Apple Music, which '
#                            'offers users a curated listening experience with '
#                            'on-demand radio stations; Apple News+, a '
#                            'subscription news and magazine service; Apple TV+, '
#                            'which offers exclusive original content; Apple '
#                            'Card, a co-branded credit card; and Apple Pay, a '
#                            'cashless payment service, as well as licenses its '
#                            'intellectual property. The company serves '
#                            'consumers, and small and mid-sized businesses; and '
#                            'the education, enterprise, and government markets. '
#                            'It distributes third-party applications for its '
#                            'products through the App Store. The company also '
#                            'sells its products through its retail and online '
#                            'stores, and direct sales force; and third-party '
#                            'cellular network carriers, wholesalers, retailers, '
#                            'and resellers. Apple Inc. was founded in 1976 and '
#                            'is headquartered in Cupertino, California.',
#     'longName': 'Apple Inc.',
#     'market': 'us_market',
#     'marketCap': 3544164073472,
#     'marketState': 'PREPRE',
#     'maxAge': 86400,
#     'messageBoardId': 'finmb_24937',
#     'mostRecentQuarter': 1735344000,
#     'netIncomeToCommon': 96150003712,
#     'nextFiscalYearEnd': 1759017600,
#     'numberOfAnalystOpinions': 39,
#     'open': 237.705,
#     'operatingCashflow': 108293996544,
#     'operatingMargins': 0.34459,
#     'overallRisk': 1,
#     'payoutRatio': 0.1571,
#     'phone': '(408) 996-1010',
#     'postMarketChange': 1.84001,
#     'postMarketChangePercent': 0.779897,
#     'postMarketPrice': 237.77,
#     'postMarketTime': 1741136395,
#     'previousClose': 238.03,
#     'priceEpsCurrentYear': 32.15497,
#     'priceHint': 2,
#     'priceToBook': 53.16133,
#     'priceToSalesTrailing12Months': 8.955337,
#     'profitMargins': 0.24295,
#     'quickRatio': 0.783,
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'quoteType': 'EQUITY',
#     'recommendationKey': 'buy',
#     'recommendationMean': 2.04444,
#     'region': 'US',
#     'regularMarketChange': -2.100006,
#     'regularMarketChangePercent': -0.8822443,
#     'regularMarketDayHigh': 240.07,
#     'regularMarketDayLow': 234.7,
#     'regularMarketDayRange': '234.7 - 240.07',
#     'regularMarketOpen': 237.705,
#     'regularMarketPreviousClose': 238.03,
#     'regularMarketPrice': 235.93,
#     'regularMarketTime': 1741122001,
#     'regularMarketVolume': 53101971,
#     'returnOnAssets': 0.22518998,
#     'returnOnEquity': 1.3652,
#     'revenueGrowth': 0.04,
#     'revenuePerShare': 25.974,
#     'sector': 'Technology',
#     'sectorDisp': 'Technology',
#     'sectorKey': 'technology',
#     'shareHolderRightsRisk': 1,
#     'sharesOutstanding': 15022100480,
#     'sharesPercentSharesOut': 0.0085,
#     'sharesShort': 127893856,
#     'sharesShortPreviousMonthDate': 1736899200,
#     'sharesShortPriorMonth': 135189465,
#     'shortName': 'Apple Inc.',
#     'shortPercentOfFloat': 0.0085,
#     'shortRatio': 2.22,
#     'sourceInterval': 15,
#     'state': 'CA',
#     'symbol': 'AAPL',
#     'targetHighPrice': 325.0,
#     'targetLowPrice': 197.0,
#     'targetMeanPrice': 252.92384,
#     'targetMedianPrice': 260.0,
#     'totalCash': 53774999552,
#     'totalCashPerShare': 3.58,
#     'totalDebt': 96798998528,
#     'totalRevenue': 395760009216,
#     'tradeable': False,
#     'trailingAnnualDividendRate': 0.99,
#     'trailingAnnualDividendYield': 0.0041591395,
#     'trailingEps': 6.25,
#     'trailingPE': 37.7488,
#     'trailingPegRatio': 2.2046,
#     'triggerable': True,
#     'twoHundredDayAverage': 226.14005,
#     'twoHundredDayAverageChange': 9.7899475,
#     'twoHundredDayAverageChangePercent': 0.043291524,
#     'typeDisp': 'Equity',
#     'volume': 53101971,
#     'website': 'https://www.apple.com',
#     'zip': '95014'}

# %%
data = yf.download("AAPL", start="2020-01-01", end="2024-01-01")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.716057  72.776583  71.466797  71.721004  135480400
# 2020-01-03  72.009117  72.771745  71.783962  71.941328  146322800
# 2020-01-06  72.582916  72.621654  70.876083  71.127873  118387200
# 2020-01-07  72.241539  72.849216  72.021223  72.592586  108872000
# 2020-01-08  73.403664  73.706294  71.943774  71.943774  132079200

# %%
data = yf.download(["AAPL", "MSFT"], start="2020-01-01", end="2024-01-01")
data.head()
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price           Close                   High                    Low  \
# Ticker           AAPL        MSFT       AAPL        MSFT       AAPL
# Date
# 2020-01-02  72.716057  153.323242  72.776583  153.428246  71.466797
# 2020-01-03  72.009117  151.414108  72.771745  152.683690  71.783962
# 2020-01-06  72.582916  151.805527  72.621654  151.872354  70.876083
# 2020-01-07  72.241539  150.421371  72.849216  152.416422  72.021223
# 2020-01-08  73.403664  152.817337  73.706294  153.495089  71.943774
#
# Price                        Open                 Volume
# Ticker            MSFT       AAPL        MSFT       AAPL      MSFT
# Date
# 2020-01-02  151.137280  71.721004  151.566834  135480400  22622100
# 2020-01-03  150.879551  71.941328  151.127749  146322800  21116200
# 2020-01-06  149.400002  71.127873  149.944115  118387200  20813700
# 2020-01-07  150.173188  72.592586  152.082331  108872000  21634100
# 2020-01-08  150.774555  71.943774  151.710031  132079200  27746500
